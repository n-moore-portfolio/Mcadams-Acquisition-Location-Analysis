# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#import data
climate_data = pd.read_csv(r"C:\Users\Nathan\Documents\Python Projects\Mcadams Projects\Best Locations\data\climate data\National_Risk_Index_Counties.csv")

# %%
#view data
climate_data.head()
# Out:
#    OBJECTID  NRI_ID     STATE STATEABBRV  STATEFIPS   COUNTY COUNTYTYPE  \
# 0         1  C21115  Kentucky         KY         21  Johnson     County
# 1         2  C21117  Kentucky         KY         21   Kenton     County
# 2         3  C21119  Kentucky         KY         21    Knott     County
# 3         4  C21121  Kentucky         KY         21     Knox     County
# 4         5  C21123  Kentucky         KY         21    Larue     County
#
#    COUNTYFIPS  STCOFIPS  POPULATION  ...   WNTW_EALA     WNTW_EALT  WNTW_EALS  \
# 0         115     21115       23356  ...    4.235939  47363.199731  19.448529
# 1         117     21117      159720  ...   44.606252  64259.532691  21.530408
# 2         119     21119       16346  ...    0.023091  30809.754620  16.851393
# 3         121     21121       31883  ...    0.082573  61427.308851  21.209328
# 4         123     21123       14193  ...  246.668438  12870.385216  12.597091
#
# ...

# %%
#create a dataframe with the necessary columns
climate_data_df = climate_data.filter(items=['NRI_ID','STATE','STATEFIPS','COUNTY','COUNTYFIPS','STCOFIPS','POPULATION','BUILDVALUE','AGRIVALUE','RISK_SCORE','RISK_RATNG','EAL_SCORE','EAL_RATNG','EAL_VALB','EAL_VALA','SOVI_SCORE','SOVI_RATNG','RESL_SCORE','RESL_RATNG'])
climate_data_df
# Out:
#       NRI_ID     STATE  STATEFIPS      COUNTY  COUNTYFIPS  STCOFIPS  \
# 0     C21115  Kentucky         21     Johnson         115     21115
# 1     C21117  Kentucky         21      Kenton         117     21117
# 2     C21119  Kentucky         21       Knott         119     21119
# 3     C21121  Kentucky         21        Knox         121     21121
# 4     C21123  Kentucky         21       Larue         123     21123
# ...      ...       ...        ...         ...         ...       ...
# 3137  C56037   Wyoming         56  Sweetwater          37     56037
# 3138  C56039   Wyoming         56       Teton          39     56039
# 3139  C56041   Wyoming         56       Uinta          41     56041
# 3140  C56043   Wyoming         56    Washakie          43     56043
# 3141  C56045   Wyoming         56      Weston          45     56045
#
#       POPULATION   BUILDVALUE  AGRIVALUE  RISK_SCORE      RISK_RATNG  \
# 0          23356   1924008000     706000    9.281419  Relatively Low
# ...

# %%
#filter data for high risk scores
climate_risk_scores = climate_data_df.sort_values(['RISK_SCORE'], ascending=[False])
climate_risk_scores
# Out:
#       NRI_ID       STATE  STATEFIPS         COUNTY  COUNTYFIPS  STCOFIPS  \
# 1271  C06037  California          6    Los Angeles          37      6037
# 2623  C48201       Texas         48         Harris         201     48201
# 1429  C12086     Florida         12     Miami-Dade          86     12086
# 1285  C06065  California          6      Riverside          65      6065
# 828   C36005    New York         36          Bronx           5     36005
# ...      ...         ...        ...            ...         ...       ...
# 2929  C51610    Virginia         51   Falls Church         610     51610
# 1329  C08035    Colorado          8        Douglas          35      8035
# 1479  C13053     Georgia         13  Chattahoochee          53     13053
# 2673  C48301       Texas         48         Loving         301     48301
# 2902  C51107    Virginia         51        Loudoun         107     51107
#
#       POPULATION    BUILDVALUE  AGRIVALUE  RISK_SCORE RISK_RATNG   EAL_SCORE  \
# ...

# %%
#export data
climate_risk_scores.to_excel(r'C:\Users\Nathan\Documents\Python Projects\Mcadams Projects\Best Locations\data\climate_risk_scores.xlsx')
